# %% [markdown]
# ## Globals

# %%
folder_data = '/Users/lviotti/Library/CloudStorage/Dropbox/Work/Kitzes/datasets/omao-individual-recordings/audio-clean'

# %% [markdown]
# ## Import libraries and set-up global configurations

# %%
import os

from opensoundscape.spectrogram import Spectrogram
from opensoundscape.audio import Audio
import pandas as pd
import matplotlib.pyplot as plt
import IPython.display as ipd

# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'
plt.rcParams['figure.figsize'] = [12,5]

# %%
from annotation import *

# %% [markdown]
# ## Annotation

# %%
os.chdir(folder_data)
annotate(
    # scores_file ='clps3s.csv',
    scores_file = 'clps3s-centered-round2.csv',
    valid_annotations = [0,1,'u','w'],
    index_cols = ['file', 'start_time', 'end_time'])
# Out:
# 1435 of 1436
# Clip: ('/Users/lviotti/Library/CloudStorage/Dropbox/Work/Kitzes/datasets/omao-individual-recordings/audio-clean/r16/16-20190123-1001.wav', 771.785275, 774.785275)
# None
#                 <audio  controls="controls" autoplay="autoplay">
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
# Enter annotation. Valid options are ['0', '1', 'u', 'w'].
#  1
# Enter any notes you would like to make or press enter to skip.
#
# Does this look right? Pressing 'r' to try again.
#                                                                              low_freq  \
# file                                               start_time end_time
# /Users/lviotti/Library/CloudStorage/Dropbox/Wor... 0.000000   3.000000       0.000000
#                                                    0.703364   3.703364       0.000000
# ...
